# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\hlaw\Downloads\2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables (1).csv')

# %%
df
# Out:
#        School DBN                     School Name       School Type  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt  General Academic
# 1          01M034  P.S. 034 Franklin D. Roosevelt  General Academic
# 2          01M034  P.S. 034 Franklin D. Roosevelt  General Academic
# 3          01M140          P.S. 140 Nathan Straus  General Academic
# 4          01M140          P.S. 140 Nathan Straus  General Academic
# ...           ...                             ...               ...
# 212326     84X717            Icahn Charter School  General Academic
# 212327     84X717            Icahn Charter School  General Academic
# 212328     84X717            Icahn Charter School  General Academic
# 212329     84X717            Icahn Charter School  General Academic
# 212330     84X717            Icahn Charter School  General Academic
#
#        School Level                 Regents Exam  Year Demographic Category  \
# ...

# %%
#View only Demographic Category: All students in 20th distact
df2= df['School DBN'].str.contains('20K') & (df['Demographic Category'] == 'All Students') & (df['School Level'] == 'Junior High-Intermediate-Middle')
df[df2]
# Out:
#       School DBN                            School Name       School Type  \
# 12058     20K062                      J.H.S. 062 Ditmas  General Academic
# 12059     20K062                      J.H.S. 062 Ditmas  General Academic
# 12060     20K062                      J.H.S. 062 Ditmas  General Academic
# 12061     20K062                      J.H.S. 062 Ditmas  General Academic
# 12062     20K062                      J.H.S. 062 Ditmas  General Academic
# 12063     20K062                      J.H.S. 062 Ditmas  General Academic
# 12064     20K062                      J.H.S. 062 Ditmas  General Academic
# 12065     20K062                      J.H.S. 062 Ditmas  General Academic
# 12083     20K187  The Christa McAuliffe School\I.S. 187  General Academic
# 12084     20K187  The Christa McAuliffe School\I.S. 187  General Academic
# 12085     20K187  The Christa McAuliffe School\I.S. 187  General Academic
# 12088     20K201           J.H.S. 201 The Dyker Heights  General Academic
# ...

# %%
# Remove unnecessary columns 
df3 = df[df2].drop(['School Type','Demographic Variable'], axis=1)
df3
# Out:
#       School DBN                            School Name  \
# 12058     20K062                      J.H.S. 062 Ditmas
# 12059     20K062                      J.H.S. 062 Ditmas
# 12060     20K062                      J.H.S. 062 Ditmas
# 12061     20K062                      J.H.S. 062 Ditmas
# 12062     20K062                      J.H.S. 062 Ditmas
# 12063     20K062                      J.H.S. 062 Ditmas
# 12064     20K062                      J.H.S. 062 Ditmas
# 12065     20K062                      J.H.S. 062 Ditmas
# 12083     20K187  The Christa McAuliffe School\I.S. 187
# 12084     20K187  The Christa McAuliffe School\I.S. 187
# 12085     20K187  The Christa McAuliffe School\I.S. 187
# 12088     20K201           J.H.S. 201 The Dyker Heights
# 12089     20K201           J.H.S. 201 The Dyker Heights
# 12090     20K201           J.H.S. 201 The Dyker Heights
# 12091     20K201           J.H.S. 201 The Dyker Heights
# 12092     20K201           J.H.S. 201 The Dyker Heights
# ...

# %%
#Groupby
df3.groupby(['School Name','Year','Regents Exam'])['Mean Score'].max()
# Out:
# School Name                            Year  Regents Exam
# J.H.S. 062 Ditmas                      2015  Common Core Algebra                68.5
#                                              Common Core English                   s
#                                              Living Environment                 82.4
#                                        2016  Common Core Algebra                77.6
#                                              Living Environment                 81.8
#                                        2017  Common Core Algebra                79.5
#                                              Common Core English                   s
#                                              Living Environment                 79.6
# J.H.S. 201 The Dyker Heights           2015  Common Core Algebra                83.6
#                                              Physical Settings/Earth Science    84.4
# ...

# %%
#Would like to know which school has the highest Mean Algebra Score in 2016

df3['Mean Score'].max()
# Out:
# 's'

# %%
#Since there is 's' in mean score, I would like to remove the S. 

df4 = df3.drop(index=df3[df3['Mean Score']== 's'].index)
df4
# Out:
#       School DBN                            School Name  \
# 12058     20K062                      J.H.S. 062 Ditmas
# 12059     20K062                      J.H.S. 062 Ditmas
# 12060     20K062                      J.H.S. 062 Ditmas
# 12063     20K062                      J.H.S. 062 Ditmas
# 12064     20K062                      J.H.S. 062 Ditmas
# 12065     20K062                      J.H.S. 062 Ditmas
# 12083     20K187  The Christa McAuliffe School\I.S. 187
# 12084     20K187  The Christa McAuliffe School\I.S. 187
# 12085     20K187  The Christa McAuliffe School\I.S. 187
# 12088     20K201           J.H.S. 201 The Dyker Heights
# 12089     20K201           J.H.S. 201 The Dyker Heights
# 12090     20K201           J.H.S. 201 The Dyker Heights
# 12091     20K201           J.H.S. 201 The Dyker Heights
# 12092     20K201           J.H.S. 201 The Dyker Heights
# 12093     20K201           J.H.S. 201 The Dyker Heights
# 12094     20K201           J.H.S. 201 The Dyker Heights
# ...

# %%
#Filter to only see Algebra in 2016
df5=df4.loc[(df4['Regents Exam'] == 'Common Core Algebra') & (df4['Year'] == 2016)]

# %%
df5
# Out:
#       School DBN                            School Name  \
# 12059     20K062                      J.H.S. 062 Ditmas
# 12084     20K187  The Christa McAuliffe School\I.S. 187
# 12089     20K201           J.H.S. 201 The Dyker Heights
# 12096     20K220            J.H.S. 220 John J. Pershing
# 12105     20K223                 J.H.S. 223 The Montauk
# 12116     20K227           J.H.S. 227 Edward B. Shallow
# 12129     20K259            J.H.S. 259 William Mckinley
#
#                           School Level         Regents Exam  Year  \
# 12059  Junior High-Intermediate-Middle  Common Core Algebra  2016
# 12084  Junior High-Intermediate-Middle  Common Core Algebra  2016
# 12089  Junior High-Intermediate-Middle  Common Core Algebra  2016
# 12096  Junior High-Intermediate-Middle  Common Core Algebra  2016
# 12105  Junior High-Intermediate-Middle  Common Core Algebra  2016
# 12116  Junior High-Intermediate-Middle  Common Core Algebra  2016
# ...

# %%
#Graph on how many student took the Alebra test in 2016
df5.sort_values(by='Mean Score').plot(kind='bar',x='School Name',y= 'Total Tested')
# Out:
# <AxesSubplot:xlabel='School Name'>
